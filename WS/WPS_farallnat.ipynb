# %% [markdown]
# # WPS test for event attribution with FARallnat

# %%
##############################
# load the required libraries 
#############################

# from owslib.wps import WebProcessingService, monitorExecution, printInputOutput
from owslib.wps import WebProcessingService, monitorExecution, printInputOutput, ComplexDataInput


from os import system, environ
import time

environ["UNICORN_CMD_ARGS"] = "-t 900"

# %%
#################################################
# connect to the compute provider hosting the WPS
#################################################

#wps_url = "http://birdhouse.lsce.ipsl.fr:8096/wps"
wps_url = "http://localhost:8096/wps"
wps_url = "http://localhost:5000/wps"
#wps_url = "http://wps-test.ipsl.jussieu.fr:8096/wps"
wps = WebProcessingService(url=wps_url, verbose=True)

# %%
##########################################
# print some information about the service
##########################################

print wps.identification.title + ':'
print '#############'
for process in wps.processes:
    print '%s : \t %s' % (process.identifier, process.abstract)

# %%
#################################################
# print some information about a specific process
#################################################

# to recieve informations uncomment the follwing lines

p = wps.describeprocess(identifier='FARallnat')
for input in p.dataInputs:
    printInputOutput(input)
    print '\n'

# %%
# get information about the call command:
wps.execute?

# %%
#####################
# execute the process
#####################
from owslib.wps import WebProcessingService, monitorExecution, printInputOutput, ComplexDataInput

from os import system, environ
import time

wps_url = "http://localhost:5000/wps"
wps_url = "http://localhost:8096/wps"
wps = WebProcessingService(url=wps_url, verbose=False)

print("fffff")
# call asyncon with sleepSecs
#print ComplexDataInput("http://tamtam.com").getXml()
start_time = time.time()

inputs = [("dataset", ComplexDataInput("https://www.esrl.noaa.gov/psd/thredds/fileServer/Datasets/ncep.reanalysis.derived/surface/air.mon.ltm.nc"))]
inputs.append(("variable", "air"))

#print inputs

anaxecute0 = wps.execute(
    identifier="simple_plot", 
    inputs=inputs)#,
    #mode='async')



start_time = time.time()

files = ["tas_Amon_CNRM-CM5_historical_r1i1p1_185001-189912.nc", 
         "tas_Amon_CNRM-CM5_historical_r1i1p1_190001-194912.nc", 
         "tas_Amon_CNRM-CM5_historical_r1i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_200601-205512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_205601-210012.nc"
        ]
files = ['file://' + "/home/sthao/1_Data/Thao/CMIP5_files_test/" + f for f in files]

#print files
#print ComplexDataInput(files)

inputs = [("files", ComplexDataInput(f)) for f in files]
inputs.append(("xname","tas"))
inputs.append(("yname","tas"))
#print inputs

outputs = [("output", True)]

anaxecute0 = wps.execute(
    identifier = "FARallnat", 
    inputs = inputs,
    output = outputs,
    mode = 'async',
    lineage = True
)

monitorExecution(anaxecute0, sleepSecs=1)

print time.time() - start_time, "seconds"

print anaxecute0.getStatus()
# Out:
# fffff
# _async:
# True
# output:
# None
# <wps100:Execute xmlns:wps100="http://www.opengis.net/wps/1.0.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" service="WPS" version="1.0.0" xsi:schemaLocation="http://www.opengis.net/wps/1.0.0 http://schemas.opengis.net/wps/1.0.0/wpsExecute_request.xsd"><ows110:Identifier xmlns:ows110="http://www.opengis.net/ows/1.1">simple_plot</ows110:Identifier><wps100:DataInputs><wps100:Input><ows110:Identifier xmlns:ows110="http://www.opengis.net/ows/1.1">dataset</ows110:Identifier><wps100:Reference xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="https://www.esrl.noaa.gov/psd/thredds/fileServer/Datasets/ncep.reanalysis.derived/surface/air.mon.ltm.nc"/></wps100:Input><wps100:Input><ows110:Identifier xmlns:ows110="http://www.opengis.net/ows/1.1">variable</ows110:Identifier><wps100:Data><wps100:LiteralData>air</wps100:LiteralData></wps100:Data></wps100:Input></wps100:DataInputs></wps100:Execute>
# ...

# %%
print anaxecute0.processOutputs
for o in anaxecute0.processOutputs:
    print o.reference

# %%
#####################
# execute the process
#####################
from owslib.wps import WebProcessingService, monitorExecution, printInputOutput, ComplexDataInput

from os import system, environ
import time

wps_url = "http://localhost:5000/wps"
#wps_url = "http://wps-test.ipsl.jussieu.fr:8096/wps"
wps = WebProcessingService(url=wps_url, verbose=True)

print("fffff")
# call asyncon with sleepSecs
#print ComplexDataInput("http://tamtam.com").getXml()
start_time = time.time()

inputs = [("dataset", ComplexDataInput("https://www.esrl.noaa.gov/psd/thredds/fileServer/Datasets/ncep.reanalysis.derived/surface/air.mon.ltm.nc"))]
inputs.append(("variable", "air"))

#print inputs

anaxecute0 = wps.execute(
    identifier="simple_plot", 
    inputs=inputs)#,
    #mode='async')



start_time = time.time()


files = ["tas_Amon_CNRM-CM5_historical_r10i1p1_185001-189912.nc", 
         "tas_Amon_CNRM-CM5_historical_r10i1p1_190001-194912.nc", 
         "tas_Amon_CNRM-CM5_historical_r10i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r1i1p1_185001-189912.nc", 
         "tas_Amon_CNRM-CM5_historical_r1i1p1_190001-194912.nc", 
         "tas_Amon_CNRM-CM5_historical_r1i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r2i1p1_185001-189912.nc", 
         "tas_Amon_CNRM-CM5_historical_r2i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r2i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r3i1p1_185001-189912.nc",
         "tas_Amon_CNRM-CM5_historical_r3i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r3i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r4i1p1_185001-189912.nc",
         "tas_Amon_CNRM-CM5_historical_r4i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r4i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r5i1p1_185001-189912.nc",
         "tas_Amon_CNRM-CM5_historical_r5i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r5i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r6i1p1_185001-189912.nc",
         "tas_Amon_CNRM-CM5_historical_r6i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r6i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r7i1p1_185001-189912.nc",
         "tas_Amon_CNRM-CM5_historical_r7i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r7i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r8i1p1_185001-189912.nc",
         "tas_Amon_CNRM-CM5_historical_r8i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r8i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_historical_r9i1p1_185001-189912.nc",
         "tas_Amon_CNRM-CM5_historical_r9i1p1_190001-194912.nc",
         "tas_Amon_CNRM-CM5_historical_r9i1p1_195001-200512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r10i1p1_200601-205512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r10i1p1_205601-210012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_200601-205512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_205601-210012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_210101-215012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_215101-220012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_220101-225012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r1i1p1_225101-230012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r2i1p1_200601-205512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r2i1p1_205601-210012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r4i1p1_200601-205512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r4i1p1_205601-210012.nc",
         "tas_Amon_CNRM-CM5_rcp85_r6i1p1_200601-205512.nc",
         "tas_Amon_CNRM-CM5_rcp85_r6i1p1_205601-210012.nc"
        ]
files = ['file://' + "/home/sthao/1_Data/Thao/CMIP5_files_test/" + f for f in files]

#print files
#print ComplexDataInput(files)

inputs = [("files", ComplexDataInput(f)) for f in files]
inputs.append(("xname","tas"))
inputs.append(("yname","tas"))

#print inputs

anaxecute0 = wps.execute(
    identifier="FARallnat", 
    inputs=inputs,
    mode='async')

monitorExecution(anaxecute0, sleepSecs=1)

print time.time() - start_time, "seconds"

print anaxecute0.getStatus()

# %%
monitorExecution(anaxecute0, sleepSecs=10)
